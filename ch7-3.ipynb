# %% [markdown]
# ## 모듈 만들기

# %% [markdown]
# - 파이썬 파일을 만들고 외부에서 읽어들이면 모듈이 됨
# - 모듈을 구조화해서 패키지를 만드는 기능을 제공

# %%
import testmodule as test

radius = test.number_input()
print(test.get_circumference(radius))
print(test.get_circle_area(radius))
# Out:
# 62.83184
# 314.1592

# %% [markdown]
# ### __name__ == "__main__"

# %% [markdown]
# - 프로그램의 진입점을 엔트리 포인트 또는 메인이라고 함
#     - 엔트리 포인트/메인 내부에서의 __name__은 "__main__"
# - 모듈 내부에서 __name__을 출력하면 모듈의 이름

# %%
import main_test as test

radius = test.number_input()
print(test.get_circumference(radius))
print(test.get_circle_area(radius))
# Out:
# get_circunrference(10): 62.83184
# get_cirle_area(10): 314.1592
# 62.83184
# 314.1592

# %% [markdown]
# ### 패키지

# %% [markdown]
# - 패키지: 모듈이 모여서 구조를 이룸

# %%
# %run main.py
# Out:
# a 모듈의 변수
# b 모듈의 변수

# %% [markdown]
# - 패키지를 읽을때 어떤 저리를 수행하거나 패키지 내부의 모듈들을 한꺼번에 가져오고 싶을 댸 패키지 폴더 내부에 __init__.py 파일을 만들어 사용
#     - __init__.py는 해당 폴더가 패키지임을 알려주고, 패키지와 관련된 초기화 처리를 하는 파일
#     - __all__이라는 이름의 리스에 지정한 모듈들이 from〈패키지 이름〉import *를 할 때 전부 읽어 들여짐
