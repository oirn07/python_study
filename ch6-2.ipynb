# %% [markdown]
# # 예외 고급

# %% [markdown]
# ### 예외 객체
# - Exception

# %%
# 예외 객체
try:
    number_input_a = int(input("정수 입력> "))
    print("원의 반지름", number_input_a)
    print("원의 둘레", 2* 3.14* number_input_a)
    print("원의 넓이", 3.14 * number_input_a * number_input_a)
    
except Exception as exception:
    print("type(exception)", type(exception))
    print("exception", exception)
# Out:
# type(exception) <class 'ValueError'>
# exception invalid literal for int() with base 10: 'yes!!'

# %% [markdown]
# ### 예외 구분하기
# - 예외 객체를 사용해서 except 구문을 if 조건문처럼 사용해서 예외를 구분

# %%
# 여러 가지 예외가 발생할 수 있는 코드
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
except Exception as exception:
    print("type(exception)", type(exception))
    print("exception:", exception)
# Out:
# type(exception) <class 'IndexError'>
# exception: list index out of range

# %% [markdown]
# ### 예외 구분하기
# - except 구문 뒤에 예외의 종류를 입력해서 예외를 구분할 수 있다
# ![alt text](image.png)

# %%
#예외 구분하기

list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))

except ValueError:
    print("정수를 입력해 주세요!")    
except IndexError:
    print("리스트의 인덱스를 벗어났어요!")
# Out:
# 리스트의 인덱스를 벗어났어요!

# %% [markdown]
# ### 예외 구분 구문과 예외 객체
# - 예외를 구분할 때 각각의 except 구문 뒤에 예외 객체를 붙여 활용 가능(as 키워드 이용)

# %%
# 예외 구문과 예외 객체
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))

except ValueError as exception:
    print("정수를 입력해 주세요!")    
    print("exception:", exception)
    
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요!")
    print("exception:", exception)
# Out:
# 리스트의 인덱스를 벗어났어요!
# exception: list index out of range

# %% [markdown]
# ### 모든 예외 잡기
# - 마지막에 Exception을 넣어서 프로그램이 죽지 않게 함

# %%
# 예외 처리를 했지만 예외를 못 잡는 경우
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
    예외.발생해주세요() #잡지 않은 예외 발생
except ValueError as exception:
    print("정수를 입력해 주세요!")    
    print("exception:", exception)
    
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요!")
    print("exception:", exception)
# Out:
# 1번째 요소: 273
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       5     number_input = int(input("정수 입력> "))
#       6     print("{}번째 요소: {}".format(number_input, list_number[number_input]))
# ----> 7     예외.발생해주세요() #잡지 않은 예외 발생
#       8 except ValueError as exception:
#       9     print("정수를 입력해 주세요!")
#
# NameError: name '예외' is not defined

# %%
# 모든 예외 잡기
list_number = [52, 273, 32, 72, 100]

try:
    number_input = int(input("정수 입력> "))
    print("{}번째 요소: {}".format(number_input, list_number[number_input]))
    예외.발생해주세요() #잡지 않은 예외 발생
    
except ValueError as exception:
    print("정수를 입력해 주세요!")    
    print("exception:", exception)
    
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요!")
    print("exception:", exception)
    
except Exception as exception:
    print("미리 파악하지 못한 에러가 발생했습니다.")
    print("exception:", exception)
# Out:
# 1번째 요소: 273
# 미리 파악하지 못한 에러가 발생했습니다.
# exception: name '예외' is not defined

# %% [markdown]
# ### raise 구문
# - 구현되지 않은 부분므로 일부러 예외를 발생시켜 프로그램이 죽게 만들어 잊어버리지 않도록 함
