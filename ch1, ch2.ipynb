# %% [markdown]
# ### 문장 (statement)
# - 실행할 수 있는 코드의 최소 단위

# %% [markdown]
# ### 식별자 (identifier)
# - 프로그래밍 언어에서 이름을 붙일 때 사용하는 단어
# - 주로 변수/함수 이름 등
#
# 식별자 규칙
# • 키워드를사용하면 안 됩니다.
# • 특수 문자는 언더 바(_)만 허용됩니다.
# • 숫자로시작하면 안 됩니다.
# • 공백을포함할 수 없습니다.
#
# 스네이크 케이스
# - 단어 사이에 언더 바(_) 기호를 붙여 만든 식별자
# 캐멀 케이스
# - 단어들의 첫 글자를 대문자로 만든 식별자

# %%
#주석 처리
print("Hello! Python Programming...") #문자열을 출력합니다
# Out:
# Hello! Python Programming...

# %% [markdown]
# ### 출력 print()
# - print() 함수는 다음과 같이 함수의 괄호 안 에 출력하고 싶은 것을 나열해서 사용

# %%
#하나만 출력하기
print("HeUo Python Programming... 1")
#여러개 출력하기
print(52, 273, "Hello")
#줄바꿈하기
print("# 아무것도 출력하지 않습니다.")
print("— 확인 전용선 ---")
print()
print("— 확인 전용선 ---")
# Out:
# HeUo Python Programming... 1
# 52 273 Hello
# # 아무것도 출력하지 않습니다.
# — 확인 전용선 ---
#
# — 확인 전용선 ---

# %% [markdown]
# ### 자료형과 기본 자료형
# - 문자열(string)： 메일 제목, 메시지 내용 등
# - 숫자(number): 물건의 가격, 학생의 성적 등
# - 불(boolean)： 친구의 로그인 상태 등
#
# 자료형 확인하기: tyPe( )함수 사용

# %%
print(type("안녕하세요"))
print(type(273))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### 문자열 만들기

# %%
#큰따옴표로 문자열 만들기
print("안녕하세요")
#작은따옴표로 문자열 만들기
print('안녕하세요')
#문자열 내부에 따옴표 넣기
print('"안녕하세요"라고 말했습니다') #큰따옴표를 문자열 내부에 넣고 싶으면 작은따옴표로 문자열을 만든다
print("'배가 고픕니다'라고 생각했습니다'") #작은따옴표를 문자열에 넣고 싶으면 큰따옴표로 문자열을 만든다
#이스케이프 문자를 사용해 문자열 만들기
print("\"안녕하세요\"라고 말했습니다") #\"：큰따옴표를 의미
print('\'배가 고픕니다\'라고 생각했습니다') #\'：작은따옴표를 의미

print("안녕하세요\n안녕하세요") #\n： 줄바꿈을 의미
print("안녕하세요\t안녕하세요") #\t： 탭을 의미

#여러 줄 문자열 만들기
#여러 줄 문자열: 큰따옴표 또는 작은따 옴표를 세 번 반복한 기호
print("""
      동해물과 백두산이 마르고 닳도록 
      하느님이 보우하사 우리나라 만세 
      무궁화 삼천리 화려강산 대한사람 
      대한으로 길이 보전하세
      """)
#만약 의도하지 않은 줄바꿈이 들어가지 않게 하려면 \ 기호를 사용
print("""\
      동해물과 백두산이 마르고 닳도록
      하느님이 보우하사 우리나라 만세
      무궁화 삼천리 화려강산 대한사람
      대한으로 길이 보전하세\
      """)
# Out:
# 안녕하세요
# 안녕하세요
# "안녕하세요"라고 말했습니다
# '배가 고픕니다'라고 생각했습니다'
# "안녕하세요"라고 말했습니다
# '배가 고픕니다'라고 생각했습니다
# 안녕하세요
# 안녕하세요
# 안녕하세요	안녕하세요
#
#       동해물과 백두산이 마르고 닳도록
#       하느님이 보우하사 우리나라 만세
#       무궁화 삼천리 화려강산 대한사람
#       대한으로 길이 보전하세
#
#       동해물과 백두산이 마르고 닳도록
#       하느님이 보우하사 우리나라 만세
#       무궁화 삼천리 화려강산 대한사람
#       대한으로 길이 보전하세

# %% [markdown]
# ### 문자열 연산자
# - 문자열에는 + 연산자로 문자열 연결 연산을 적용

# %%
print("안녕" + "하세요")
print("안녕하세요" + "!")
# print("안녕하세요" + "1") 문자열은 무조건 문자열끼리 + 연산자를 사용해서 연결
print("안녕하세요" + "1")

#문자열 반복 연산자: *
print("안녕하세요" * 3)
# Out:
# 안녕하세요
# 안녕하세요!
# 안녕하세요1
# 안녕하세요안녕하세요안녕하세요

# %% [markdown]
# 문자 선택 연산자（인덱싱）: []
# 문자 선택 연산자는 문자열 내부의 문자 하나를 선택하는 연산자
# 대괄호 [] 안에 선택할 문자 의 위치를 지정하며 이를 인덱스라고 함
# - 제로 인덱스: 숫자를 0부터 셈
# - 원 인덱스: 숫자를 1부터 셈
#
# lndexError(index out of range) 예외: 리스트/문자열의 수를 넘는 요소/글자를 선택할 때 발생

# %%
print("문자 선택 연산자에 대해 알아볼까요?")
print("안녕하세요"[0])
print("안녕하세요"[1])
print("안녕하세요"[2])
print("안녕하세요"[3])
print("안녕하세요"[4])

#문자열 범위 선택 연산자（슬라이싱）: [:] 범위를 지정한다
print("안녕하세요"[1:4])
print("안녕하세요"[1:]) #가장 최대 위치까지 
print("안녕하세요"[:3]) #가장 앞쪽 위치까지
# Out:
# 문자 선택 연산자에 대해 알아볼까요?
# 안
# 녕
# 하
# 세
# 요
# 녕하세
# 녕하세요
# 안녕하

# %% [markdown]
# 문자열의 길이 구하기
# len()함수 사용

# %%
print(len("안녕하세요"))
# Out:
# 5

# %% [markdown]
# ### 숫자의 종류
# - int： 정수
# - float： 부동소수점（실수）

# %% [markdown]
# ### 숫자 연산자
# - 사칙연산자: +, -, *, /
# - 정수 나누기 연산자: //
# - 나머지 연산자: %
# - 제곱 연산자: **

# %%
#정수나누기 연산자
print("3 // 2 =", 3 // 2)
#나머지 연산자
print("5 % 2 =", 5 % 2)
#제곱 연산자
print("2 ** 3 =", 2 ** 3)
# Out:
# 3 // 2 = 1
# 5 % 2 = 1
# 2 ** 3 = 8

# %% [markdown]
# ### 연산자의 우선순위
# - 숫자를 계산할 떄는 곱셈과 나눗셈이 덧셈과 뺄셈보다 우선
# - 곱셈/나눗셈과 덧셈/ 뺄셈처럼 같은 우선순위를 가지는 연산자는 왼쪽에서 오른쪽 순서로 계산
#
# TypeError 예외
# - 서로 다른 자료를 연산하면 TypeError라는 예외가 발생

# %% [markdown]
# ### 변수 만들기 / 사용하기
# - 변수를 선언
# - 변수에 값을 할당
# - 변수를 참조

# %%
#변수 선언과 할당
pi = 3.14159265
r = 10

#변수 참조
print("원주율 =", pi)
print("반지름 =", r)
print("원의 둘레 =", 2 * pi * r)
print("원의 넓이 =", pi * r * r)
# Out:
# 원주율 = 3.14159265
# 반지름 = 10
# 원의 둘레 = 62.831853
# 원의 넓이 = 314.159265

# %% [markdown]
# ### 복합 대입 연산자
# +=: 숫자 덧셈 후 대입
# -=: 숫자 뺄셈 후 대입
# *-: 숫자 곱셈 후 대입
# /-: 숫자 나눗셈 후 대입
# %-: 숫자의 나머지를 구한 후 대입
# **=: 숫자 제곱 후 대입
#
# ### 문자열 복합 대입 연산자
# +=: 문자열 연결 후 대입
# *=: 문자열 반복 후 대입

# %% [markdown]
# ### 사용자 입력: input()
# - 명령 프롬프트에서 사용자로부터 데이터를 입력받을 때 input() 함수를 사용

# %%
#입력을 받습니다.
string = input("입력> ")

#출력합니다.
print("자료:", string)
print("자료형", type(string))
# Out:
# 자료:
# 자료형 <class 'str'>

# %% [markdown]
# ### 문자열을 숫자로 바꾸기
# - int() 함수: 문자열을 int 자료형으로 변환. int는 정수형을 의미
# - float() 함수: 문자열을 float 자료형으로 변환. float는 실수형 또는 부동 소수점을 의미
#
# ValueError 예외: 자료형을 변환할 때 ‘변환할 수 없는 것’을 변환하려고 하면 ValueError 예외가 발생
# - 숫자가 아닌 것을 숫자로 변환려고 할 때
# - 소수점이 있는 숫자 형식의 문자열을 int() 함수로 변환하려고 할 때

# %%
output_a = int("52")
output_b = float("52.273")
print(type(output_a), output_a)
print(type(output_b), output_b)

#int()함수와 float()함수 조합
input_a = float(input("첫 번째 숫자> "))
input_b = float(input("두 번째 숫자> "))
print("덧셈 결과：", input_a + input_b)
print("뺄셈 결과：", input_a - input_b)
print("곱셈 결과：", input_a * input_b)
print("나눗셈 결과：", input_a / input_b)
# Out:
# <class 'int'> 52
# <class 'float'> 52.273
# 덧셈 결과： 325.0
# 뺄셈 결과： 221.0
# 곱셈 결과： 14196.0
# 나눗셈 결과： 5.25

# %% [markdown]
# ### 숫자를 문자열로 바꾸기: str()함수
# - 다른 자료형의 값을 str() 함수의 매개변수에 넣으면 문자열로 변환

# %%
output_a = str(52)
output_b = str(52.273)
print(type(output_a), output_a)
print(type(output_b), output_b)
# Out:
# <class 'str'> 52
# <class 'str'> 52.273

# %%
# inch 단위를 cm 단위로 변경하기

#숫자를 입력
raw_input = input("inch 단위의 숫자를 입력해주세요")

#입력받은 데이터를 숫자 단위로 변경하고, cm 단위로 변경
inch = int(raw_input)
cm = inch * 2.54

#출력
print(inch, "inch는 cm 단위로", cm, "cm입니다")
# Out:
# 27 inch는 cm 단위로 68.58 cm입니다

# %% [markdown]
# ### 문자열의 format() 함수
# format() 함수는 문자열이 가지고 있는 함수
# 중괄호{}를 포함한 문자열 뒤에 마침표(.)를 찍고 format() 함수를 사용하는데, 중괄호의 개수와 format 함수 괄호 안 매개변수의 개수는 반드시 같아야 한다

# %%
# format() 함수로 숫자를 문자열로 변환
string_a = "{}".format(10)
#출력
print(string_a)
print(type(string_a))
# Out:
# 10
# <class 'str'>

# %%
# format() 함수로 숫자를 문자열로 변환
format_a = "{}만 원,".format(5000)
format_b = "파이썬 열공하여 첫 연봉 {}만 원 만들기 ".format(5000)
format_c = "{} {} {}".format(3000, 4000, 5000)
format_d = "{} {} {}".format(1, "문자열", True)
#출력
print(format_a)
print(format_b)
print(format_c)
print(format_d)
# Out:
# 5000만 원,
# 파이썬 열공하여 첫 연봉 5000만 원 만들기
# 3000 4000 5000
# 1 문자열 True

# %%
# format() 함수의 다양한 기능
#정수
output_a = "{:d}".format(52)

#특정 칸에 출력하기
output_b = "{:5d}".format(52) #5칸
output_c = "{:10d}".format(52) #10칸

#빈칸을 0으로 채우기
output_d = "{:05d}".format(52) #양수
output_e = "{:05d}".format(-52) #음수
print("# 기본")
print(output_a)
print("# 특정 칸에 출력하기")
print(output_b)
print(output_c)
print("# 빈칸을 0으로 채우기")
print(output_d)
print(output_e)
# Out:
# # 기본
# 52
# # 특정 칸에 출력하기
#    52
#         52
# # 빈칸을 0으로 채우기
# 00052
# -0052

# %%
#조합하기
output_h = "{:+5d}".format(52) # 기호를 뒤로 밀기: 양수
output_i = "{:+5d}".format(-52) # 기호를 뒤로 밀기: 음수
output_j = "{:=+5d}".format(52) # 기호를 앞으로 밀기: 양수
output_k = "{:=+5d}".format(-52) # 기호를 앞으로 밀기: 음수
output_l = "{:+05d}".format(52) #0으로 채우기: 양수
output_m = "{:+05d}".format(-52) #0으로 채우기: 음수

print(output_h)
print(output_i)
print(output_j)
print(output_k)
print(output_l)
print(output_m)
# Out:
#   +52
#   -52
# +  52
# -  52
# +0052
# -0052

# %% [markdown]
# ### 대소문자 바꾸기: upper()와 lower()
# - upperO 함수는 문자열의 알파벳을 대문자로, lower() 함수는 문자열의 알파벳을 소문자로 만든다
#
# ### 문자열 양옆의 공백 제거하기: strip()
# - strip() 함수는 문자열 양옆의 공백을 제거
# - 왼쪽의 공백을 제거하는 lstrip() 함수와 오른쪽의 공백을 제거하는 rstrip() 함수
#
# ### 문자열의 구성 파악하기: isOO()
#
# ### 문자열 자르기: split（）
# - 문자열을 특정한 문자로 자를 때는 split（ ） 함수를 사용

# %%
# 도전문제 1
# 구의 부피와 겉넓이
raw_input = input("구의 반지름을 입력해주세요: ")

r = int(raw_input)
v = 4/3* 3.141592 * r*r*r
a = 4 * 3.141592 * r*r
print("= 구의 부피는", v, "입니다.")
print("= 구의 겉넓이는", a, "입니다.")
# Out:
# = 구의 부피는 523.5986666666666 입니다.
# = 구의 겉넓이는 314.1592 입니다.

# %%
# 도전문제 2 
# 피타고라스의 정리
a_input = input("밑변의 길이를 입력해주세요: ")
b_input = input("높이의 길이를 입력해주세요: ")

a = int(a_input)
b = int(b_input)


c = (a*a + b*b) **(0.5)
print("= 빗변의 길이는", c, "입니다.")
# Out:
# = 빗변의 길이는 5.0 입니다.
